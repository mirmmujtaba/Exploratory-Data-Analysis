# %% [markdown]
# # PART I-A

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading Data stores in csv format
df = pd.read_csv('ab40c054-5031-4376-b52e-9813e776f65e.csv')

# %%
# Dropping rows in accordance with the instruction
df = df.drop([5, 10], axis=0)

# %%
# Making necessary changes to fill NaN values
df_df = df.transpose().iloc[2:-1, :].rename(columns = {0 : df['Items  Description'][0] + ', 11-12', 1 : df['Items  Description'][1] + ', 12-13', 2 : df['Items  Description'][2] + ', 13-14', 
                                              3 : df['Items  Description'][3] + ', 14-15', 4 : df['Items  Description'][4] + ', 15-16', 6 : df['Items  Description'][6] + ', 12-13', 7 : df['Items  Description'][7] + ', 13-14', 8 : df['Items  Description'][8] + ', 14-15', 
                                              9 : df['Items  Description'][9] + ', 15-16'})
df_df = df_df.apply(pd.to_numeric)
df_df.fillna(df_df.median(), inplace=True)
df0 = df_df.transpose()

# %%
# Selecting the required portion of the Dataframe
df1 = df0.iloc[6:, :]
df1
# Out:
#                                       Andhra Pradesh   Arunachal Pradesh  \
# (% Growth over previous year), 13-14            12.85              16.38
# (% Growth over previous year), 14-15            13.40              14.79
# (% Growth over previous year), 15-16            15.85              12.07
#
#                                       Assam  Bihar  Chhattisgarh    Goa  \
# (% Growth over previous year), 13-14  13.31  12.30         16.44  -5.77
# (% Growth over previous year), 14-15  11.45  17.92         13.69  13.12
# (% Growth over previous year), 15-16  13.19  10.59         10.98  10.75
#
#                                       Gujarat  Haryana  Himachal Pradesh  \
# (% Growth over previous year), 13-14    11.47    15.45             14.42
# (% Growth over previous year), 14-15    10.82     9.18             10.14
# (% Growth over previous year), 15-16    11.09    10.91             11.09
#
#                                       Jammu & Kashmir     ...      Tamil Nadu  \
# ...

# %%
# Creating a new dataframe to which will be used to plot the average growth of GDP of individual states
x = pd.Series(['Andhra Pradesh ',
       'Arunachal Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Goa', 'Gujarat',
       'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
       'Karnataka', 'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
       'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Punjab', 'Rajasthan',
       'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
       'Uttarakhand', 'West Bengal1', 'Andaman & Nicobar Islands',
       'Chandigarh', 'Delhi', 'Puducherry'], name = 'State')
y = pd.Series([df1['Andhra Pradesh '].mean(), df1['Arunachal Pradesh'].mean(), df1['Assam'].mean(), df1['Bihar'].mean(), 
               df1['Chhattisgarh'].mean(), df1['Goa'].mean(), df1['Gujarat'].mean(), df1['Haryana'].mean(), 
               df1['Himachal Pradesh'].mean(), df1['Jammu & Kashmir'].mean(), df1['Jharkhand'].mean(), df1['Karnataka'].mean(), 
               df1['Kerala'].mean(), df1['Madhya Pradesh'].mean(), df1['Maharashtra'].mean(), df1['Manipur'].mean(), 
               df1['Meghalaya'].mean(), df1['Mizoram'].mean(), df1['Nagaland'].mean(), df1['Odisha'].mean(), 
               df1['Punjab'].mean(), df1['Rajasthan'].mean(), df1['Sikkim'].mean(), df1['Tamil Nadu'].mean(), 
               df1['Telangana'].mean(), df1['Tripura'].mean(), df1['Uttar Pradesh'].mean(), df1['Uttarakhand'].mean(), 
               df1['West Bengal1'].mean(), df1['Andaman & Nicobar Islands'].mean(), df1['Chandigarh'].mean(), 
               df1['Delhi'].mean(), df1['Puducherry'].mean()], name = 'Average Growth')
df2 = pd.concat([x, y], axis=1)
df2 = df2.sort_values(by = ['Average Growth'], ascending = False)

# %%
National_Average_Growth_Rate = np.array([df1['Andhra Pradesh '].mean(), df1['Arunachal Pradesh'].mean(), df1['Assam'].mean(), df1['Bihar'].mean(), 
               df1['Chhattisgarh'].mean(), df1['Goa'].mean(), df1['Gujarat'].mean(), df1['Haryana'].mean(), 
               df1['Himachal Pradesh'].mean(), df1['Jammu & Kashmir'].mean(), df1['Jharkhand'].mean(), df1['Karnataka'].mean(), 
               df1['Kerala'].mean(), df1['Madhya Pradesh'].mean(), df1['Maharashtra'].mean(), df1['Manipur'].mean(), 
               df1['Meghalaya'].mean(), df1['Mizoram'].mean(), df1['Nagaland'].mean(), df1['Odisha'].mean(), 
               df1['Punjab'].mean(), df1['Rajasthan'].mean(), df1['Sikkim'].mean(), df1['Tamil Nadu'].mean(), 
               df1['Telangana'].mean(), df1['Tripura'].mean(), df1['Uttar Pradesh'].mean(), df1['Uttarakhand'].mean(), 
               df1['West Bengal1'].mean(), df1['Andaman & Nicobar Islands'].mean(), df1['Chandigarh'].mean(), 
               df1['Delhi'].mean(), df1['Puducherry'].mean()]).mean()
print('National Average Growth Rate is:')
print(National_Average_Growth_Rate)
print('')
print('Growth Rate of Jammu and Kashmir is:')
print(df1['Jammu & Kashmir'].mean())
# Out:
# National Average Growth Rate is:
# 12.132424242424245
#
# Growth Rate of Jammu and Kashmir is:
# 10.9

# %%
# Plotting the average growth of GDP of individual states
plt.figure(figsize = (10, 10))
plt.title('Average growth rate of GDP of individual states')
sns.barplot( x = 'Average Growth', y = 'State', data = df2)

# %% [markdown]
# #### Looking at the plot above, Mizoram has the highest average growth rate followed by
# #### others and so on. My  home state, Jammu and Kashmir is lagging behind but is better than Sikkim,
# #### Odisha, Meghalaya and Goa. Average growth rate of my home state i.e 10.9 is less than the national average,
# #### national average being 12.13.

# %%
# Plot of total GDP w.r.t the individual states
s1 = pd.Series(df_df.transpose().loc['(% Growth over previous year), 15-16'].index)
s2 = pd.Series(df_df.transpose().loc['GSDP - CURRENT PRICES (` in Crore), 15-16'].values)
df4 = pd.concat([s1, s2], axis=1)
df4 = df4.rename({0 : 'State', 1 : 'Total GDP'}, axis = 1)
df4 = df4.sort_values(by = ['Total GDP'], ascending = False)
# Plotting total GDP w.r.t the individual states
plt.figure(figsize = (10, 10))
plt.title('Total GDP w.r.t the individual states')
sns.barplot(x = 'Total GDP', y = 'State', data = df4)

# %%
# States having Lowest and Highest GDP value
Lowest_GDP_States = df_df['GSDP - CURRENT PRICES (` in Crore), 15-16'].sort_values()[:5]
Highest_GDP_States = df_df['GSDP - CURRENT PRICES (` in Crore), 15-16'].sort_values(ascending = False)[:5]
print('5 Lowest GDP States:')
print(Lowest_GDP_States)
print('')
print('')
print('5 Highest GDP States:')
print(Highest_GDP_States)
# Out:
# 5 Lowest GDP States:
# Sikkim               16637.0
# Arunachal Pradesh    18784.0
# Puducherry           26533.0
# Meghalaya            26745.0
# Chandigarh           30304.0
# Name: GSDP - CURRENT PRICES (` in Crore), 15-16, dtype: float64
#
#
# 5 Highest GDP States:
# Tamil Nadu         1212668.0
# Uttar Pradesh      1153795.0
# Karnataka          1027068.0
# Gujarat             994316.0
# Andhra Pradesh      609934.0
# Name: GSDP - CURRENT PRICES (` in Crore), 15-16, dtype: float64

# %% [markdown]
# # PART I-B

# %%
# Reading the required data
df_index = pd.read_csv('NAD-Himachal_Pradesh-GSVA_cur_2014-15.csv')['Item']
df_Himachal_Pradesh = pd.read_csv('NAD-Himachal_Pradesh-GSVA_cur_2014-15.csv').rename(columns = {'2014-15' : 'Himachal Pradesh'})['Himachal Pradesh']
df_Maharashtra = pd.read_csv('NAD-Maharashtra-GSVA_cur_2014-15.csv').rename(columns = {'2014-15' : 'Maharashtra'})['Maharashtra']
df_Punjab = pd.read_csv('NAD-Punjab-GSVA_cur_2014-15.csv').rename(columns = {'2014-15' : 'Punjab'})['Punjab']
df_Rajasthan = pd.read_csv('NAD-Rajasthan-GSVA_cur_2014-15.csv').rename(columns = {'2014-15' : 'Rajasthan'})['Rajasthan']
df_Mizoram = pd.read_csv('NAD-Mizoram-GSVA_cur_2014-15.csv').rename(columns = {'2014-15' : 'Mizoram'})['Mizoram']
df_Nagaland = pd.read_csv('NAD-Nagaland-GSVA_cur_2014-15.csv').rename(columns = {'2014-15' : 'Nagaland'})['Nagaland']
df_Tripura = pd.read_csv('NAD-Tripura-GSVA_cur_2014-15.csv').rename(columns = {'2014-15' : 'Tripura'})['Tripura']
df_Manipur = pd.read_csv('NAD-Manipur-GSVA_cur_2014-15.csv', encoding = 'cp1252').rename(columns = {'2014-15' : 'Manipur'})['Manipur']
df_Jammu_Kashmir = pd.read_csv('NAD-Jammu_Kashmir-GSVA_cur_2015-16.csv').rename(columns = {'2014-15' : 'Jammu and Kashmir'})['Jammu and Kashmir']
df_Andhra_Pradesh = pd.read_csv('NAD-Andhra_Pradesh-GSVA_cur_2016-17.csv').rename(columns = {'2014-15' : 'Andhra Pradesh'})['Andhra Pradesh']
df_Arunachal_Pradesh = pd.read_csv('NAD-Arunachal_Pradesh-GSVA_cur_2015-16.csv').rename(columns = {'2014-15' : 'Arunachal Pradesh'})['Arunachal Pradesh']
df_Assam = pd.read_csv('NAD-Assam-GSVA_cur_2015-16.csv').rename(columns = {'2014-15' : 'Assam'})['Assam']
df_Bihar = pd.read_csv('NAD-Bihar-GSVA_cur_2015-16.csv').rename(columns = {'2014-15' : 'Bihar'})['Bihar']
df_Chhattisgarh = pd.read_csv('NAD-Chhattisgarh-GSVA_cur_2016-17.csv').rename(columns = {'2014-15' : 'Chhattisgarh'})['Chhattisgarh']
df_Goa = pd.read_csv('NAD-Goa-GSVA_cur_2015-16.csv').rename(columns = {'2014-15' : 'Goa'})['Goa']
df_Gujarat = pd.read_csv('NAD-Gujarat-GSVA_cur_2015-16.csv').rename(columns = {'2014-15' : 'Gujarat'})['Gujarat']
df_Haryana = pd.read_csv('NAD-Haryana-GSVA_cur_2016-17.csv').rename(columns = {'2014-15' : 'Haryana'})['Haryana']
df_Sikkim = pd.read_csv('NAD-Sikkim-GSVA_cur_2015-16.csv').rename(columns = {'2014-15' : 'Sikkim'})['Sikkim']
df_Tamil_Nadu = pd.read_csv('NAD-Tamil_Nadu-GSVA_cur_2016-17.csv').rename(columns = {'2014-15' : 'Tamil Nadu'})['Tamil Nadu']
df_Telangana = pd.read_csv('NAD-Telangana-GSVA_cur_2016-17.csv').rename(columns = {'2014-15' : 'Telangana'})['Telangana']
df_Uttar_Pradesh = pd.read_csv('NAD-Uttar_Pradesh-GSVA_cur_2015-16.csv').rename(columns = {'2014-15' : 'Uttar Pradesh'})['Uttar Pradesh']
df_Uttarakhand = pd.read_csv('NAD-Uttarakhand-GSVA_cur_2015-16.csv').rename(columns = {'2014-15' : 'Uttarakhand'})['Uttarakhand']
df_Jharkhand = pd.read_csv('NAD-Jharkhand-GSVA_cur_2015-16.csv').rename(columns = {'2014-15' : 'Jharkhand'})['Jharkhand']
df_Kerala = pd.read_csv('NAD-Kerala-GSVA_cur_2015-16.csv').rename(columns = {'2014-15' : 'Kerala'})['Kerala']
df_Madhya_Pradesh = pd.read_csv('NAD-Madhya_Pradesh-GSVA_cur_2016-17.csv').rename(columns = {'2014-15' : 'Madhya Pradesh'})['Madhya Pradesh']
df_Meghalaya = pd.read_csv('NAD-Meghalaya-GSVA_cur_2016-17.csv').rename(columns = {'2014-15' : 'Meghalaya'})['Meghalaya']
df_Odisha = pd.read_csv('NAD-Odisha-GSVA_cur_2016-17.csv').rename(columns = {'2014-15' : 'Odisha'})['Odisha']
df_Delhi = pd.read_csv('NAD-Delhi-GSVA_cur_2016-17.csv').rename(columns = {'2014-15' : 'Delhi'})['Delhi']
df_Chandigarh = pd.read_csv('NAD-Chandigarh-GSVA_cur_2015-16.csv').rename(columns = {'2014-15' : 'Chandigarh'})['Chandigarh']
df_Puducherry = pd.read_csv('NAD-Puducherry-GSVA_cur_2016-17.csv').rename(columns = {'2014-15' : 'Puducherry'})['Puducherry']

# %%
# Ordering the data in the required form
result1 = pd.concat([df_index, df_Himachal_Pradesh, df_Maharashtra, df_Punjab, df_Rajasthan, df_Mizoram, df_Nagaland, df_Tripura, df_Manipur,
                     df_Jammu_Kashmir, df_Andhra_Pradesh, df_Arunachal_Pradesh, df_Assam, df_Bihar, df_Chhattisgarh, df_Goa, df_Gujarat,
                     df_Haryana, df_Sikkim, df_Tamil_Nadu, df_Telangana, df_Uttar_Pradesh, df_Uttarakhand, df_Jharkhand, df_Kerala,
                     df_Madhya_Pradesh, df_Meghalaya, df_Odisha, df_Delhi, df_Chandigarh, df_Puducherry], axis=1)
result1.fillna(result1.median(), inplace = True)
result2 = pd.concat([pd.Series(pd.Series(result1.columns)[1:].values), pd.Series(result1.iloc[32][1:].values)], axis = 1).rename({0 : 'State', 1 : 'GDP Per Capita'}, axis = 1)
result2 = result2[(result2['State'] != 'Delhi') & (result2['State'] != 'Chandigarh') & (result2['State'] != 'Puducherry')]
result1 = result1.iloc[:, :28]

# %%
# Plotting the GDP per capita for all states
result2 = result2.sort_values(by = ['GDP Per Capita'], ascending = False)
plt.figure(figsize = (10, 10))
plt.title('GDP per capita for all states')
sns.barplot(x = 'GDP Per Capita', y = 'State', data = result2)

# %%
# Printing 5 states having the highest and the lowest GDP per capita 
print('5 highest GDP per capita')
print(result2[:5])
print('')
print('')
print('5 lowest GDP per capita')
print(result2[-5:].sort_values(by = 'GDP Per Capita'))
# Out:
# 5 highest GDP per capita
#           State GDP Per Capita
# 14          Goa         271793
# 17       Sikkim         240274
# 16      Haryana         164077
# 23       Kerala         154778
# 21  Uttarakhand         153076
#
#
# 5 lowest GDP per capita
#             State GDP Per Capita
# 12          Bihar          33954
# 20  Uttar Pradesh          49450
# 7         Manipur          58442
# 11          Assam          60621
# 22      Jharkhand          62091

# %%
# Printing the ratio of the highest GDP per capita to the lowest GDP per capita
print('The ratio of the highest GDP per capita to lowest GDP per capita is:')
print(result2.iloc[0].values[-1]/result2.iloc[-1].values[-1])
# Out:
# The ratio of the highest GDP per capita to lowest GDP per capita is:
# 8.004741709371503

# %%
# Plot the percentage contribution of the primary, secondary and tertiary sectors as a 
# percentage of the total GDP for all the states

GDP_list = []
for i in result1[result1['Item'] == 'Gross State Domestic Product'].transpose()[1:].values:
    for p in i:
        GDP_list.append(p)
GDP_list = pd.Series(GDP_list)

from textwrap import wrap

states = pd.Series(result1.columns)[1:]
index = np.arange(len(states))

primary = []
for i in result1[result1['Item'] == 'Primary'].transpose()[1:].values:
    for p in i:
        primary.append(p)
primary = 100*((pd.Series(primary))/(GDP_list))

secondary = []
for i in result1[result1['Item'] == 'Secondary'].transpose()[1:].values:
    for p in i:
        secondary.append(p)
secondary = 100*((pd.Series(secondary))/(GDP_list))

tertiary = []
for i in result1[result1['Item'] == 'Tertiary'].transpose()[1:].values:
    for p in i:
        tertiary.append(p)
tertiary = 100*((pd.Series(tertiary))/(GDP_list))

states = ['\n'.join(wrap(state, 10)) for state in states]

plt.figure(figsize = (27, 10))

bar_primary = plt.bar(x = index, height = primary, width = 0.5, label = 'Primary')
bar_secondary = plt.bar(x = index, height = secondary, width = 0.5, bottom = primary, label = 'Secondary')
bar_tertiary = plt.bar(x = index, height = tertiary, width = 0.5, bottom = secondary+primary, label = 'Tertiary')

plt.legend((bar_primary, bar_secondary, bar_tertiary), ('Primary', 'Secondary', 'Tertiary'))

plt.xlabel('States')
plt.ylabel('Primary, Secondary, Tertiary')

plt.xticks(index, states)
plt.autoscale()

# %%
# Calculating the quantiles of GDP Per Capita
result2['GDP Per Capita'].quantile([0.2, 0.5, 0.85, 1])
# Out:
# 0.20     65187
# 0.50     97687
# 0.85    153246
# 1.00    271793
# Name: GDP Per Capita, dtype: object

# %%
# Creating groups of data where the groups are C1, C2, C3 and C4
s = result1.transpose()
s.columns = s.iloc[0]
s = s[1:]
s['Quantile'] = s['Per Capita GSDP (Rs.)'].apply(lambda x : 'C4' if x <= 65187 else 'C3' if (x > 65187) and (x <= 97687) else
                                           'C2' if (x > 97687) and (x <= 153246) else 'C1')
ss = s.groupby(by = 'Quantile').sum()
ss = ss[['Agriculture, forestry and fishing', 'Mining and quarrying', 'Manufacturing', 'Electricity, gas, water supply & other utility services',
      'Construction', 'Trade, repair, hotels and restaurants', 'Transport, storage, communication & services related to broadcasting',
      'Financial services', 'Real estate, ownership of dwelling & professional services', 'Public administration', 'Other services']]
C1 = ss.iloc[0].sort_values(ascending = False)
C2 = ss.iloc[1].sort_values(ascending = False)
C3 = ss.iloc[2].sort_values(ascending = False)
C4 = ss.iloc[3].sort_values(ascending = False)

# %%
# Percentage contribution of sub-sectors w.r.t the GSDP 
ss['% Agriculture, forestry and fishing'] = 100*(ss['Agriculture, forestry and fishing']/s.groupby(by = 'Quantile').sum()['Gross State Domestic Product'])
ss['% Mining and quarrying'] = 100*(ss['Mining and quarrying']/s.groupby(by = 'Quantile').sum()['Gross State Domestic Product'])
ss['% Manufacturing'] = 100*(ss['Manufacturing']/s.groupby(by = 'Quantile').sum()['Gross State Domestic Product'])
ss['% Electricity, gas, water supply & other utility services'] = 100*(ss['Electricity, gas, water supply & other utility services']/s.groupby(by = 'Quantile').sum()['Gross State Domestic Product'])
ss['% Construction'] = 100*(ss['Construction']/s.groupby(by = 'Quantile').sum()['Gross State Domestic Product'])
ss['% Trade, repair, hotels and restaurants'] = 100*(ss['Trade, repair, hotels and restaurants']/s.groupby(by = 'Quantile').sum()['Gross State Domestic Product'])
ss['% Transport, storage, communication & services related to broadcasting'] = 100*(ss['Transport, storage, communication & services related to broadcasting']/s.groupby(by = 'Quantile').sum()['Gross State Domestic Product'])
ss['% Financial services'] = 100*(ss['Financial services']/s.groupby(by = 'Quantile').sum()['Gross State Domestic Product'])
ss['% Real estate, ownership of dwelling & professional services'] = 100*(ss['Real estate, ownership of dwelling & professional services']/s.groupby(by = 'Quantile').sum()['Gross State Domestic Product'])
ss['% Public administration'] = 100*(ss['Public administration']/s.groupby(by = 'Quantile').sum()['Gross State Domestic Product'])
ss['% Other services'] = 100*(ss['Other services']/s.groupby(by = 'Quantile').sum()['Gross State Domestic Product'])
sss = ss[['% Agriculture, forestry and fishing', '% Mining and quarrying', '% Manufacturing', '% Electricity, gas, water supply & other utility services',
    '% Construction', '% Trade, repair, hotels and restaurants', '% Transport, storage, communication & services related to broadcasting',
    '% Financial services', '% Real estate, ownership of dwelling & professional services', '% Public administration',
    '% Other services']]

# %%
# Sorting the list for the desired results
C1 = sss.loc['C1'].sort_values(ascending = False)
C2 = sss.loc['C2'].sort_values(ascending = False)
C3 = sss.loc['C3'].sort_values(ascending = False)
C4 = sss.loc['C4'].sort_values(ascending = False)

# %%
print('For C1 category, sub-sectors that contribute to 80% of the GSDP are:\n')
print(C1.iloc[:7])
# Out:
# For C1 category, sub-sectors that contribute to 80% of the GSDP are:
#
# Item
# % Real estate, ownership of dwelling & professional services              14.461049
# % Agriculture, forestry and fishing                                       14.119213
# % Trade, repair, hotels and restaurants                                   13.730076
# % Manufacturing                                                           13.498187
# % Construction                                                            11.051090
# % Other services                                                           7.907258
# % Transport, storage, communication & services related to broadcasting     6.689409
# Name: C1, dtype: float64

# %%
print('For C2 category, sub-sectors that contribute to 80% of the GSDP are:\n')
print(C2.iloc[:8])
# Out:
# For C2 category, sub-sectors that contribute to 80% of the GSDP are:
#
# Item
# % Manufacturing                                                           18.453915
# % Agriculture, forestry and fishing                                       14.411490
# % Real estate, ownership of dwelling & professional services              13.122549
# % Trade, repair, hotels and restaurants                                   10.328383
# % Construction                                                             7.170844
# % Other services                                                           6.429728
# % Financial services                                                       6.236341
# % Transport, storage, communication & services related to broadcasting     6.167913
# Name: C2, dtype: float64

# %%
print('For C3 category, sub-sectors that contribute to 80% of the GSDP are:\n')
print(C3.iloc[:8])
# Out:
# For C3 category, sub-sectors that contribute to 80% of the GSDP are:
#
# Item
# % Agriculture, forestry and fishing                                       21.420049
# % Manufacturing                                                           13.489416
# % Trade, repair, hotels and restaurants                                   10.270273
# % Real estate, ownership of dwelling & professional services               9.721330
# % Construction                                                             8.738575
# % Other services                                                           7.052936
# % Mining and quarrying                                                     6.933431
# % Transport, storage, communication & services related to broadcasting     5.811948
# Name: C3, dtype: float64

# %%
print('For C4 category, sub-sectors that contribute to 80% of the GSDP are:\n')
print(C4.iloc[:7])
# Out:
# For C4 category, sub-sectors that contribute to 80% of the GSDP are:
#
# Item
# % Agriculture, forestry and fishing                                       24.323490
# % Trade, repair, hotels and restaurants                                   11.783216
# % Manufacturing                                                           10.712459
# % Real estate, ownership of dwelling & professional services              10.365410
# % Construction                                                             9.764521
# % Transport, storage, communication & services related to broadcasting     6.941761
# % Other services                                                           6.799089
# Name: C4, dtype: float64

# %%
sns.barplot(x = pd.Series(C1.values), y = pd.Series(C1.index))
plt.title('Contribution of the sub-sectors as a percentage of the GSDP for C1')
plt.xlabel('Percentage contribution')
plt.ylabel('Differenct Sub-Sectors')
# Out:
# Text(0,0.5,'Differenct Sub-Sectors')

# %%
sns.barplot(x = pd.Series(C2.values), y = pd.Series(C2.index))
plt.title('Contribution of the sub-sectors as a percentage of the GSDP for C2')
plt.xlabel('Percentage contribution')
plt.ylabel('Differenct Sub-Sectors')
# Out:
# Text(0,0.5,'Differenct Sub-Sectors')

# %%
sns.barplot(x = pd.Series(C3.values), y = pd.Series(C3.index))
plt.title('Contribution of the sub-sectors as a percentage of the GSDP for C3')
plt.xlabel('Percentage contribution')
plt.ylabel('Differenct Sub-Sectors')
# Out:
# Text(0,0.5,'Differenct Sub-Sectors')

# %%
sns.barplot(x = pd.Series(C4.values), y = pd.Series(C4.index))
plt.title('Contribution of the sub-sectors as a percentage of the GSDP for C4')
plt.xlabel('Percentage contribution')
plt.ylabel('Differenct Sub-Sectors')
# Out:
# Text(0,0.5,'Differenct Sub-Sectors')

# %% [markdown]
# #### If we look at C3 and C4, the major contributor to their economy is Agriculture, forestry and fishing sub-sector.
# #### C1 is the group having the most GDP per capita but unlike C3 and C4, the major contributor in it's economy isn't agricultural
# #### rather Real estate, ownership of dwelling & professional services sub-sector.

# %% [markdown]
# #### Looking at the plot, since Agriculture, forestry and fishing sub-sector is placed higher consistently so this sub-sector
# #### seem to be correlated with high GDP.

# %% [markdown]
# #### C1 really needs to focus on Mining and Quarrying since it's contribution is less than even 1%.
# #### C2 also needs to focus on Mining and Quarrying since it is the least contributor here also.
# #### C3 needs to focus on Financial Services and Electricity, gas and other utility services since both of them are nearly equally the
# #### least contributors to the economy.
# #### C4 should focus on Financial Services, Mining and Quarrying and Eectriclity, gas, water supply and other utility services
# #### since they are the least contributors and also since C4 is the least GDP per capita group it need to focus on more sub-sectors.

# %% [markdown]
# # Part-II: GDP and Education Dropout Rates

# %%
# Reading the required data
GDP_PER_CAPITA = pd.Series([pd.read_csv('NAD-Himachal_Pradesh-GSVA_cur_2014-15.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Maharashtra-GSVA_cur_2014-15.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Punjab-GSVA_cur_2014-15.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Rajasthan-GSVA_cur_2014-15.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Mizoram-GSVA_cur_2014-15.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Nagaland-GSVA_cur_2014-15.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Tripura-GSVA_cur_2014-15.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Manipur-GSVA_cur_2014-15.csv', encoding = 'cp1252')['2014-15'].iloc[-1],
pd.read_csv('NAD-Jammu_Kashmir-GSVA_cur_2015-16.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Andhra_Pradesh-GSVA_cur_2016-17.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Arunachal_Pradesh-GSVA_cur_2015-16.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Assam-GSVA_cur_2015-16.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Bihar-GSVA_cur_2015-16.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Chhattisgarh-GSVA_cur_2016-17.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Goa-GSVA_cur_2015-16.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Gujarat-GSVA_cur_2015-16.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Haryana-GSVA_cur_2016-17.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Sikkim-GSVA_cur_2015-16.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Tamil_Nadu-GSVA_cur_2016-17.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Telangana-GSVA_cur_2016-17.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Uttar_Pradesh-GSVA_cur_2015-16.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Uttarakhand-GSVA_cur_2015-16.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Jharkhand-GSVA_cur_2015-16.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Kerala-GSVA_cur_2015-16.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Madhya_Pradesh-GSVA_cur_2016-17.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Meghalaya-GSVA_cur_2016-17.csv')['2014-15'].iloc[-1],
pd.read_csv('NAD-Odisha-GSVA_cur_2016-17.csv')['2014-15'].iloc[-1]])

data_II = pd.read_csv('rs_session243_au570_1.1.csv')
data_II.fillna(data_II.median(), inplace=True)

# %%
# Removing the Union territories
data_II = data_II[data_II['Level of Education - State'] != 'A & N Islands']
data_II = data_II[data_II['Level of Education - State'] != 'Chandigarh']
data_II = data_II[data_II['Level of Education - State'] != 'Daman & Dia']
data_II = data_II[data_II['Level of Education - State'] != 'Delhi']
data_II = data_II[data_II['Level of Education - State'] != 'Puducherry']
data_II = data_II[data_II['Level of Education - State'] != 'Dadar & Nagar Haveli']
data_II = data_II[data_II['Level of Education - State'] != 'Lakshadweep']
data_II = data_II[data_II['Level of Education - State'] != 'All India']

# %%
# Creating a series having values for Primary for 2014-15
data_II_Primary = pd.Series([data_II.loc[13, 'Primary - 2014-2015'], data_II.loc[20, 'Primary - 2014-2015'], data_II.loc[27, 'Primary - 2014-2015'],
                            data_II.loc[28, 'Primary - 2014-2015'], data_II.loc[23, 'Primary - 2014-2015'], data_II.loc[24, 'Primary - 2014-2015'],
                            data_II.loc[32, 'Primary - 2014-2015'], data_II.loc[21, 'Primary - 2014-2015'], data_II.loc[14, 'Primary - 2014-2015'],
                            data_II.loc[1, 'Primary - 2014-2015'], data_II.loc[2, 'Primary - 2014-2015'], data_II.loc[3, 'Primary - 2014-2015'],
                            data_II.loc[4, 'Primary - 2014-2015'], data_II.loc[6, 'Primary - 2014-2015'], data_II.loc[10, 'Primary - 2014-2015'],
                            data_II.loc[11, 'Primary - 2014-2015'], data_II.loc[12, 'Primary - 2014-2015'], data_II.loc[29, 'Primary - 2014-2015'],
                            data_II.loc[30, 'Primary - 2014-2015'], data_II.loc[31, 'Primary - 2014-2015'], data_II.loc[33, 'Primary - 2014-2015'],
                            data_II.loc[34, 'Primary - 2014-2015'], data_II.loc[15, 'Primary - 2014-2015'], data_II.loc[17, 'Primary - 2014-2015'],
                            data_II.loc[19, 'Primary - 2014-2015'], data_II.loc[22, 'Primary - 2014-2015'], data_II.loc[25, 'Primary - 2014-2015']])

# %%
# correlation of GDP per capita with dropout rates in education (primary, upper primary and secondary) 
# for the year 2014-2015 for each state

plt.title('Correlation of GDP per capita with Primary')
plt.scatter(GDP_PER_CAPITA, data_II_Primary, alpha=0.5)
print('The correlation between GDP per capita and Primary for 2014-15 is:')
print(GDP_PER_CAPITA.corr(data_II_values))
# Out:
# The correlation between GDP per capita and Primary for 2014-15 is:
# -0.4501782035792303

# %%
# Creating a series having values for Secondary for 2014-15
data_II_Secondary = pd.Series([data_II.loc[13, 'Secondary - 2014-2015'], data_II.loc[20, 'Secondary - 2014-2015'], data_II.loc[27, 'Secondary - 2014-2015'],
                            data_II.loc[28, 'Secondary - 2014-2015'], data_II.loc[23, 'Secondary - 2014-2015'], data_II.loc[24, 'Secondary - 2014-2015'],
                            data_II.loc[32, 'Secondary - 2014-2015'], data_II.loc[21, 'Secondary - 2014-2015'], data_II.loc[14, 'Secondary - 2014-2015'],
                            data_II.loc[1, 'Secondary - 2014-2015'], data_II.loc[2, 'Secondary - 2014-2015'], data_II.loc[3, 'Secondary - 2014-2015'],
                            data_II.loc[4, 'Secondary - 2014-2015'], data_II.loc[6, 'Secondary - 2014-2015'], data_II.loc[10, 'Secondary - 2014-2015'],
                            data_II.loc[11, 'Secondary - 2014-2015'], data_II.loc[12, 'Secondary - 2014-2015'], data_II.loc[29, 'Secondary - 2014-2015'],
                            data_II.loc[30, 'Secondary - 2014-2015'], data_II.loc[31, 'Secondary - 2014-2015'], data_II.loc[33, 'Secondary - 2014-2015'],
                            data_II.loc[34, 'Secondary - 2014-2015'], data_II.loc[15, 'Secondary - 2014-2015'], data_II.loc[17, 'Secondary - 2014-2015'],
                            data_II.loc[19, 'Secondary - 2014-2015'], data_II.loc[22, 'Secondary - 2014-2015'], data_II.loc[25, 'Secondary - 2014-2015']])

# %%
print('The correlation between GDP per capita and Secondary for 2014-15 is:')
print(GDP_PER_CAPITA.corr(data_II_Secondary))
plt.title('Correlation of GDP per capita with Secondary')
plt.scatter(GDP_PER_CAPITA, data_II_Secondary, alpha=0.5)
# Out:
# The correlation between GDP per capita and Secondary for 2014-15 is:
# -0.5047107886382403

# %%
# Creating a series having values for Upper Primary for 2014-15
data_II_Upper_Primary = pd.Series([data_II.loc[13, 'Upper Primary - 2014-2015'], data_II.loc[20, 'Upper Primary - 2014-2015'], data_II.loc[27, 'Upper Primary - 2014-2015'],
                            data_II.loc[28, 'Upper Primary - 2014-2015'], data_II.loc[23, 'Upper Primary - 2014-2015'], data_II.loc[24, 'Upper Primary - 2014-2015'],
                            data_II.loc[32, 'Upper Primary - 2014-2015'], data_II.loc[21, 'Upper Primary - 2014-2015'], data_II.loc[14, 'Upper Primary - 2014-2015'],
                            data_II.loc[1, 'Upper Primary - 2014-2015'], data_II.loc[2, 'Upper Primary - 2014-2015'], data_II.loc[3, 'Upper Primary - 2014-2015'],
                            data_II.loc[4, 'Upper Primary - 2014-2015'], data_II.loc[6, 'Upper Primary - 2014-2015'], data_II.loc[10, 'Upper Primary - 2014-2015'],
                            data_II.loc[11, 'Upper Primary - 2014-2015'], data_II.loc[12, 'Upper Primary - 2014-2015'], data_II.loc[29, 'Upper Primary - 2014-2015'],
                            data_II.loc[30, 'Upper Primary - 2014-2015'], data_II.loc[31, 'Upper Primary - 2014-2015'], data_II.loc[33, 'Upper Primary - 2014-2015'],
                            data_II.loc[34, 'Upper Primary - 2014-2015'], data_II.loc[15, 'Upper Primary - 2014-2015'], data_II.loc[17, 'Upper Primary - 2014-2015'],
                            data_II.loc[19, 'Upper Primary - 2014-2015'], data_II.loc[22, 'Upper Primary - 2014-2015'], data_II.loc[25, 'Upper Primary - 2014-2015']])

# %%
print('The correlation between GDP per capita and Upper Primary for 2014-15 is:')
print(GDP_PER_CAPITA.corr(data_II_Upper_Primary))
plt.title('Correlation of GDP per capita with Upper Primary')
plt.scatter(GDP_PER_CAPITA, data_II_Upper_Primary, alpha=0.5)
# Out:
# The correlation between GDP per capita and Upper Primary for 2014-15 is:
# -0.5461838808827788

# %% [markdown]
# #### As we can see the GDP per capita and the dropout rates show negative correlation in all the cases. The reason behind it
# #### can be that in this age, only the educated can make more money since eductated people occupy high positions
# #### which provide high salaries and hence they contribute more to the economy which in other terms means higher GDP
# #### per capita.
